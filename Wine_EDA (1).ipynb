# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Q1. Load the pandas library and create two different data frames, namely, df_red for holding the red wine dataset and df_white for holding the white wine dataset..

# %%
df_red = pd.read_csv("/content/winequality-red.csv",sep = ';')
df_white =pd.read_csv("/content/winequality-white.csv",sep = ',')

# %%
df_red.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol quality
# 0      9.4    good
# 1      9.8    good
# 2      9.8    good
# 3      9.8  medium
# 4      9.4    good
# 5      9.4    good
# 6      9.4    good
# 7     10.0  medium
# 8      9.5  medium
# 9     10.5    good

# %%
df_white.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
# 8                 14.0                 132.0   0.9940  3.30       0.49
# 9                 28.0                 129.0   0.9938  3.22       0.45
#
#    alcohol quality
# 0      8.8  medium
# 1      9.5  medium
# 2     10.1  medium
# 3      9.9  medium
# 4      9.9  medium
# 5     10.1  medium
# 6      9.6  medium
# 7      8.8  medium
# 8      9.5  medium
# 9     11.0  medium

# %% [markdown]
# #### Q2. Find the name of the available columns.

# %%
df_red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_white.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# #### Q3. Let's see some sample data from the red wine data frame. check the entries between the 100th and 110th rows.

# %%
df_red.loc[100:110,"fixed acidity":"quality"]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            8.3             0.610         0.30             2.1      0.084
# 101            7.8             0.500         0.30             1.9      0.075
# 102            8.1             0.545         0.18             1.9      0.080
# 103            8.1             0.575         0.22             2.1      0.077
# 104            7.2             0.490         0.24             2.2      0.070
# 105            8.1             0.575         0.22             2.1      0.077
# 106            7.8             0.410         0.68             1.7      0.467
# 107            6.2             0.630         0.31             1.7      0.088
# 108            8.0             0.330         0.53             2.5      0.091
# 109            8.1             0.785         0.52             2.0      0.122
# 110            7.8             0.560         0.19             1.8      0.104
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 100                 11.0                  50.0   0.9972  3.40       0.61
# 101                  8.0                  22.0   0.9959  3.31       0.56
# 102                 13.0                  35.0   0.9972  3.30       0.59
# 103                 12.0                  65.0   0.9967  3.29       0.51
# 104                  5.0                  36.0   0.9960  3.33       0.48
# 105                 12.0                  65.0   0.9967  3.29       0.51
# 106                 18.0                  69.0   0.9973  3.08       1.31
# 107                 15.0                  64.0   0.9969  3.46       0.79
# 108                 18.0                  80.0   0.9976  3.37       0.80
# 109                 37.0                 153.0   0.9969  3.21       0.69
# 110                 12.0                  47.0   0.9964  3.19       0.93
#
#      alcohol  quality
# 100     10.2        6
# 101     10.4        6
# 102      9.0        6
# 103      9.2        5
# 104      9.4        5
# 105      9.2        5
# 106      9.3        5
# 107      9.3        5
# 108      9.6        6
# 109      9.3        5
# 110      9.5        5

# %%
df_white.loc[100:110,"fixed acidity":"quality"]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            7.4             0.250         0.37            13.5      0.060
# 101            7.1             0.120         0.32             9.6      0.054
# 102            6.0             0.210         0.24            12.1      0.050
# 103            7.5             0.305         0.40            18.9      0.059
# 104            7.4             0.250         0.37            13.5      0.060
# 105            7.3             0.130         0.32            14.4      0.051
# 106            7.1             0.120         0.32             9.6      0.054
# 107            7.1             0.230         0.35            16.5      0.040
# 108            7.1             0.230         0.35            16.5      0.040
# 109            6.9             0.330         0.28             1.3      0.051
# 110            6.5             0.170         0.54             8.5      0.082
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 100                 52.0                 192.0   0.9975  3.00       0.44
# 101                 64.0                 162.0   0.9962  3.40       0.41
# 102                 55.0                 164.0   0.9970  3.34       0.39
# 103                 44.0                 170.0   1.0000  2.99       0.46
# 104                 52.0                 192.0   0.9975  3.00       0.44
# 105                 34.0                 109.0   0.9974  3.20       0.35
# 106                 64.0                 162.0   0.9962  3.40       0.41
# 107                 60.0                 171.0   0.9990  3.16       0.59
# 108                 60.0                 171.0   0.9990  3.16       0.59
# 109                 37.0                 187.0   0.9927  3.27       0.60
# 110                 64.0                 163.0   0.9959  2.89       0.39
#
#      alcohol  quality
# 100      9.1        5
# 101      9.4        5
# 102      9.4        5
# 103      9.0        5
# 104      9.1        5
# 105      9.2        6
# 106      9.4        5
# 107      9.1        6
# 108      9.1        6
# 109     10.3        5
# 110      8.8        6

# %% [markdown]
# #### Q4. Check the data types for each column.

# %%
df_red.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_white.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# #### Q5.Describe the data frame to get more descriptive information

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %% [markdown]
# #### Q6. Find which of the columns have null values.

# %%
df_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# #### Q7. We will continue analyzing the red wine dataset. First, we will start by exploring the most correlated columns. Second, we will compare two
# #### different columns and observe their columns.

# %%
a=df_red.corr()
a
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %% [markdown]
# #### First, start with the quality column of red wine. Plot a graph of your choice to do the same.

# %%
plt.figure(figsize=(10,7))

mask = np.triu(np.ones_like(a,dtype=bool))
sns.heatmap(a,annot=True,cmap="Reds",mask=mask)
plt.show()

# %% [markdown]
# we can see by this graph fixed acidity and citric acid are highely correlated.
# And low correaltion between PH and citric acid

# %% [markdown]
# . Let's next find out which of the columns from the red wine database are highly correlated.
# You need to confirm whether the following is **true**
# - Alcohol is positively correlated with the quality of red wine-**True**
# - Alcohol has a weak positive correlation with the pH value.**True(0.21)**
# - Citric acid and density have a strong positive correlation with fixed acidity.**True**
# - pH has a negative correlation with density, fixed acidity, citric acid, and sulfates.**True**
# Use pair plot, heatmap, etc to draw these correlations

# %% [markdown]
# #### 8. Let's next find out which of the columns from the red wine database are highly correlated.
# #### You need to confirm whether the following is true
# #### - Alcohol is positively correlated with the quality of red wine.
# #### - Alcohol has a weak positive correlation with the pH value.
# #### - Citric acid and density have a strong positive correlation with fixed acidity.
# #### - pH has a negative correlation with density, fixed acidity, citric acid, and sulfates.
# #### Use pair plot, heatmap, etc to draw these correlations.

# %%
plt.figure(figsize=(24,12))
sns.pairplot(df_red)
plt.show()

# %% [markdown]
# #### Q9. Let's see how the quality of wine varies with respect to alcohol concentration. Use a boxplot for the same.
# #### Can you draw this conclusion: The higher the alcohol concentration is, the higher the quality of the wine.

# %%
sns.boxplot(x=df_red["quality"],y=df_red["alcohol"]).set(title="quality tag")
# Out:
# [Text(0.5, 1.0, 'quality tag')]

# %% [markdown]
# -According to this box plot we can see if there is high alcohol concentration then wine has good quility and if there is low alcohol concentration then wine has low quility

# %%
df_red.head(100)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# ..            ...               ...          ...             ...        ...
# 95            4.7             0.600         0.17             2.3      0.058
# 96            6.8             0.775         0.00             3.0      0.102
# 97            7.0             0.500         0.25             2.0      0.070
# 98            7.6             0.900         0.06             2.5      0.079
# 99            8.1             0.545         0.18             1.9      0.080
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# ..                  ...                   ...      ...   ...        ...
# 95                 17.0                 106.0   0.9932  3.85       0.60
# 96                  8.0                  23.0   0.9965  3.45       0.56
# 97                  3.0                  22.0   0.9963  3.25       0.63
# 98                  5.0                  10.0   0.9967  3.39       0.56
# 99                 13.0                  35.0   0.9972  3.30       0.59
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# ..      ...      ...
# 95     12.9        6
# 96     10.7        5
# 97      9.2        5
# 98      9.8        5
# 99      9.0        6
#
# [100 rows x 12 columns]

# %% [markdown]
# #### Q10. Let's also see the correlation between the alcohol column and pH values. Use joint plot and Pearson regression for the same.

# %%
sns.jointplot(data=df_red, x="pH", y="alcohol")

# %% [markdown]
# *   pH values mostly lies in between 3-3.6.
# *   if there is high alcohol concentration then there is less pH value of wine that means wine is high acidic.

# %% [markdown]
# # Pearson Regression

# %%
corr = np.corrcoef(df_red['alcohol'], df_red['pH'])
corr
# Out:
# array([[1.        , 0.20563251],
#        [0.20563251, 1.        ]])

# %% [markdown]
# #### Q11. Create a correlation function that can give a correlation between any two columns. Name it get_correlation. Now find the correlation between
# #### alcohol and PH using this function.

# %%
def get_correlation(x,y):
    return (plt.scatter(x,y,color="red"))

# %%
get_correlation(df_red["alcohol"],df_red["pH"])
plt.xlabel("Alcohol")
plt.ylabel("pH")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# #### Q13. Find the average quality of both red wine and white wine.

# %%
df_red["quality"].mean()
# Out:
# 5.6360225140712945

# %%
df_white["quality"].mean()
# Out:
# 5.87790935075541

# %% [markdown]
# #### Q14.Let's add a new attribute, wine_category, to both data frames.

# %%
Mydataframe = df_red.reindex(columns = df_red.columns.tolist() 
                                  + ['wine_category'])
Mydataframe
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  wine_category
# 0         9.4        5            NaN
# 1         9.8        5            NaN
# 2         9.8        5            NaN
# 3         9.8        6            NaN
# 4         9.4        5            NaN
# ...       ...      ...            ...
# 1594     10.5        5            NaN
# 1595     11.2        6            NaN
# 1596     11.0        6            NaN
# 1597     10.2        5            NaN
# 1598     11.0        6            NaN
#
# [1599 rows x 13 columns]

# %%
mydframe = df_white.reindex(columns = df_white.columns.tolist() 
                                  + ['wine_category'])
mydframe
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  wine_category
# 0         8.8        6            NaN
# 1         9.5        6            NaN
# 2        10.1        6            NaN
# 3         9.9        6            NaN
# 4         9.9        6            NaN
# ...       ...      ...            ...
# 4893     11.2        6            NaN
# 4894      9.6        5            NaN
# 4895      9.4        6            NaN
# 4896     12.8        7            NaN
# 4897     11.8        6            NaN
#
# [4898 rows x 13 columns]

# %% [markdown]
# #### Q15. let's find out what are the unique values of the column quality in both types of wines.

# %%
df_red["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df_white["quality"].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %% [markdown]
# #### Q16. Although the quality column is numerical, here, we are interested in taking quality as the class. To make it clear, let's convert numerical
# #### values into categorical values.

# %%
k=df_red["quality"]
s=[]
for i in k:
  if i<=5:
    s.append("good")
  elif i>5:
    s.append("medium")
  elif i>=7:
    s.append("high")

# %%
df_red["quality"]=s

# %%
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol quality
# 0         9.4    good
# 1         9.8    good
# 2         9.8    good
# 3         9.8  medium
# 4         9.4    good
# ...       ...     ...
# 1594     10.5    good
# 1595     11.2  medium
# 1596     11.0  medium
# 1597     10.2    good
# 1598     11.0  medium
#
# [1599 rows x 12 columns]

# %% [markdown]
# #### Q17. To do so, we need a set of rules. Let's define a set of rules:
# #### quality_label - low if value <= 5, medium if value>5 and value <=7 and high if value > 7
# #### Write the code to add this quality_label column using the rule described above.

# %%
k=df_white["quality"]
d=[]
for i in k:
  if i<=5:
    d.append("good")
  elif i>5:
    d.append("medium")
  elif i>=7:
    d.append("high")

# %% [markdown]
# #### Q18. Count the number of values in each category of wine for column quality_label.

# %%
df_white["quality"]=d
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol quality
# 0         8.8  medium
# 1         9.5  medium
# 2        10.1  medium
# 3         9.9  medium
# 4         9.9  medium
# ...       ...     ...
# 4893     11.2  medium
# 4894      9.6    good
# 4895      9.4  medium
# 4896     12.8  medium
# 4897     11.8  medium
#
# [4898 rows x 12 columns]

# %%
p=df_red.groupby("quality")
p.size()
# Out:
# quality
# good      744
# medium    855
# dtype: int64

# %%
t=df_white.groupby("quality")
t.size()
# Out:
# quality
# good      1640
# medium    3258
# dtype: int64

# %%
df_red["quality"].unique()
# Out:
# array(['good', 'medium'], dtype=object)

# %% [markdown]
# #### Q19. Concatenate both red and white wine data frames now.

# %%
df_concat=pd.concat([df_red,df_white],join='outer')
df_concat.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4    good
# 1      9.8    good
# 2      9.8    good
# 3      9.8  medium
# 4      9.4    good

# %%
df_concat.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol
# count  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801
# std       0.160787     0.148806     1.192712
# min       2.720000     0.220000     8.000000
# 25%       3.110000     0.430000     9.500000
# 50%       3.210000     0.510000    10.300000
# 75%       3.320000     0.600000    11.300000
# max       4.010000     2.000000    14.900000

# %% [markdown]
# #### Q20. Reshuffle the rows for randomization.

# %%
df_concat1=df_concat.sample(frac = 1).reset_index(drop=True)

# %%
df_concat1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.1              0.46         0.20             1.9      0.077
# 1            6.2              0.10         0.41             1.0      0.040
# 2            5.8              0.30         0.33             3.5      0.033
# 3            6.6              0.64         0.28             4.4      0.032
# 4            7.8              0.28         0.34             1.6      0.028
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 28.0                  54.0  0.99560  3.37       0.64
# 1                 17.0                  76.0  0.98988  3.14       0.56
# 2                 25.0                 116.0  0.99057  3.20       0.44
# 3                 19.0                  78.0  0.99036  3.11       0.62
# 4                 32.0                 118.0  0.99010  3.00       0.38
#
#    alcohol quality
# 0     10.4  medium
# 1     11.4  medium
# 2     11.7  medium
# 3     12.9  medium
# 4     12.1  medium

# %% [markdown]
# #### Q21. Let's use the combined data frame and group them using the columns, alcohol, density, pH, and quality.

# %%
g=df_concat.groupby(["alcohol","density","pH","quality"])

# %% [markdown]
# #### Q22. How will you do a univariate analysis for numerical data . Apply the logic to do univariate analysis.
# #### Univariate Analysis With the help of Histogram

# %%
plt.hist(df_red["pH"],color="r")
# Out:
# (array([  2.,  27., 134., 361., 555., 352., 132.,  29.,   3.,   4.]),
#  array([2.74 , 2.867, 2.994, 3.121, 3.248, 3.375, 3.502, 3.629, 3.756,
#         3.883, 4.01 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Q23. Do a multivariate analysis for all the columns using heatmap.
# ##### Multivariate Analysis using Heatmap

# %%
a1=df_concat1.corr()
a1
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
#
#                        alcohol
# fixed acidity        -0.095452
# volatile acidity     -0.037640
# citric acid          -0.010493
# residual sugar       -0.359415
# chlorides            -0.256916
# free sulfur dioxide  -0.179838
# total sulfur dioxide -0.265740
# density              -0.686745
# pH                    0.121248
# sulphates            -0.003029
# alcohol               1.000000

# %%
plt.figure(figsize=(24,12))
sns.heatmap(a1,annot=True, cmap='Reds')
plt.show()

# %% [markdown]
# #### Q24. Draw a count plot for wine_category.

# %%
sns.countplot(x="quality", data=df_red)
